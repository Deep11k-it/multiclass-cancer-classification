# %%
import os
os.environ["MPLBACKEND"] = "Agg"

# %%
from tensorflow.keras.models import load_model

model = load_model("binary_cancer_model.keras")

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

def predict_cancer(img_path, model):
    # load image
    img = image.load_img(img_path, target_size=(224, 224))
    
    # convert to array
    img_array = image.img_to_array(img)
    
    # normalize
    img_array = img_array / 255.0
    
    # add batch dimension
    img_array = np.expand_dims(img_array, axis=0)
    
    # prediction
    prob = model.predict(img_array)[0][0]
    
    # decision
    label = "Cancer" if prob > 0.5 else "Non-Cancer"
    
    return label, prob

# %%
img_path = "lkl.png"

label, probability = predict_cancer(img_path, model)

print("Prediction:", label)
print("Probability:", probability)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Prediction: Non-Cancer
# Probability: 0.11756025
